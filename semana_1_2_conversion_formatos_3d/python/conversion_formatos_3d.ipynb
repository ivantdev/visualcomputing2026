# %% [markdown]
# # Taller - Conversion de Formatos 3D (Python)
#
# Notebook para ejecutar el pipeline de comparacion, conversion y visualizacion usando `trimesh`.

# %%
# Si hace falta, descomenta para instalar dependencias:
# %pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.6/317.6 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.1/101.1 kB 16.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: pyassimp is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for pyassimp ... done
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
from conversion_formatos_3d import run_workshop

base = Path('.').resolve()
run_workshop(
    models_dir=(base / '../models').resolve(),
    media_dir=(base / '../media').resolve(),
    converted_dir=(base / 'converted_models').resolve(),
    report_dir=base,
    max_plot_faces=12000,
    build_gif=True,
    with_open3d=False,
    with_assimp=False,
)
# Out:
# Formato | Archivo              | Vértices | Caras | Duplicados | Watertight | UV
# --------+----------------------+----------+-------+------------+------------+------
# GLB     | ship_in_a_bottle.glb | 44964    | 53462 | 19012      | False      | True
# OBJ     | ship_in_a_bottle.obj | 44964    | 53462 | 19009      | False      | True
# STL     | ship_in_a_bottle.stl | 160386   | 53462 | 134431     | False      | False
#
# Conversiones generadas: 6
# - /home/ivan/dev/visualcomputing2026/semana_1_2_conversion_formatos_3d/python/converted_models/ship_in_a_bottle_from_glb.obj
# - /home/ivan/dev/visualcomputing2026/semana_1_2_conversion_formatos_3d/python/converted_models/ship_in_a_bottle_from_glb.stl
# - /home/ivan/dev/visualcomputing2026/semana_1_2_conversion_formatos_3d/python/converted_models/ship_in_a_bottle_from_obj.stl
# - /home/ivan/dev/visualcomputing2026/semana_1_2_conversion_formatos_3d/python/converted_models/ship_in_a_bottle_from_obj.glb
# ...

# %%
import json

summary = json.loads((base / 'comparison_metrics.json').read_text(encoding='utf-8'))
summary
# Out:
# [{'file_name': 'ship_in_a_bottle.glb',
#   'format': 'GLB',
#   'vertices': 44964,
#   'faces': 53462,
#   'edges_unique': 95197,
#   'vertex_normals': 44964,
#   'face_normals': 53462,
#   'duplicate_vertices': 19012,
#   'duplicate_ratio': 0.422827,
#   'watertight': False,
#   'has_uv': True,
#   'bbox_x': 1.3973654222933618,
#   'bbox_y': 2.1362502704444375,
#   'bbox_z': 3.35409870926913,
#   'surface_area': 46.30952452019849,
#   'o3d_vertices': None,
#   'o3d_faces': None,
#   'o3d_has_vertex_normals': None,
#   'assimp_info': None},
#  {'file_name': 'ship_in_a_bottle.obj',
#   'format': 'OBJ',
#   'vertices': 44964,
#   'faces': 53462,
#   'edges_unique': 95197,
#   'vertex_normals': 44964,
#   'face_normals': 53462,
#   'duplicate_vertices': 19009,
#   'duplicate_ratio': 0.42276,
#   'watertight': False,
#   'has_uv': True,
#   'bbox_x': 1.39736542,
#   'bbox_y': 2.1362502699999997,
#   'bbox_z': 3.35409871,
#   'surface_area': 46.30952451813862,
#   'o3d_vertices': None,
# ...
